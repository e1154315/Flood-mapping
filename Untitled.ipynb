# %%
from train import main

main()  # 调用 train.py 中的 main 函数
# Out:
# 模型将被保存到: models/ThreeBand_opt-Adadelta_lr-1.0_rho-0.95_eps-1e-08.hdf5
# 配置模型，使用波段数：3
# 找到的匹配图像文件数量: 152
# 找到的匹配掩模文件数量: 152
# 总共有 152 张图像被分割。
# 训练集：75 张图像，占比 0.49
# 验证集：31 张图像，占比 0.20
# 测试集：46 张图像，占比 0.30
# 分割成功！
# 训练每个 epoch 的步骤数 (steps_per_epoch): 38
# 验证每个 epoch 的步骤数 (validation_steps): 16
# Epoch 1/5
# 38/38 [==============================] - 29s 593ms/step - loss: 0.9998 - dice_coefficient: 1.3838e-04 - iou: 7.0018e-05 - f1_score: 0.0000e+00 - val_loss: 0.9998 - val_dice_coefficient: 1.4095e-04 - val_iou: 7.1762e-05 - val_f1_score: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.99984, saving model to models\ThreeBand_opt-Adadelta_lr-1.0_rho-0.95_eps-1e-08.hdf5
# Epoch 2/5
# 38/38 [==============================] - 19s 504ms/step - loss: 0.9997 - dice_coefficient: 2.4264e-04 - iou: 1.2479e-04 - f1_score: 0.0000e+00 - val_loss: 0.9997 - val_dice_coefficient: 2.2866e-04 - val_iou: 1.1748e-04 - val_f1_score: 0.0000e+00
#
# ...
